# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url = "https://www.statlearning.com/s/Auto.csv"
data = pd.read_csv(url)

# %%
data = data.dropna()
data = data[data['horsepower'] != '?']

# %%
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
data.min(axis=0)
# Out:
# mpg                                 9.0
# cylinders                             3
# displacement                       68.0
# horsepower                          100
# weight                             1613
# acceleration                        8.0
# year                                 70
# origin                                1
# name            amc ambassador brougham
# dtype: object

# %%
data.max(axis=0)
# Out:
# mpg                         46.6
# cylinders                      8
# displacement               455.0
# horsepower                    98
# weight                      5140
# acceleration                24.8
# year                          82
# origin                         3
# name            vw rabbit custom
# dtype: object

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  392.000000  392.000000    392.000000   392.000000    392.000000
# mean    23.445918    5.471939    194.411990  2977.584184     15.541327
# std      7.805007    1.705783    104.644004   849.402560      2.758864
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.000000    4.000000    105.000000  2225.250000     13.775000
# 50%     22.750000    4.000000    151.000000  2803.500000     15.500000
# 75%     29.000000    8.000000    275.750000  3614.750000     17.025000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  392.000000  392.000000
# mean    75.979592    1.576531
# std      3.683737    0.805518
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
removed_rows = list(range(10,86))
mask = ~data.index.isin(removed_rows)
removed = data[mask]
removed.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  317.000000  317.000000    317.000000   317.000000    317.000000
# mean    24.374763    5.381703    187.880126  2938.854890     15.704101
# std      7.872565    1.658135    100.169973   811.640668      2.719913
# min     11.000000    3.000000     68.000000  1649.000000      8.500000
# 25%     18.000000    4.000000    101.000000  2215.000000     14.000000
# 50%     23.900000    4.000000    146.000000  2795.000000     15.500000
# 75%     30.500000    6.000000    250.000000  3520.000000     17.300000
# max     46.600000    8.000000    455.000000  4997.000000     24.800000
#
#              year      origin
# count  317.000000  317.000000
# mean    77.123028    1.599369
# std      3.127158    0.819308
# min     70.000000    1.000000
# 25%     75.000000    1.000000
# 50%     77.000000    1.000000
# 75%     80.000000    2.000000
# max     82.000000    3.000000

# %%
pd.plotting.scatter_matrix(data)
# Out:
# array([[<Axes: xlabel='mpg', ylabel='mpg'>,
#         <Axes: xlabel='cylinders', ylabel='mpg'>,
#         <Axes: xlabel='displacement', ylabel='mpg'>,
#         <Axes: xlabel='weight', ylabel='mpg'>,
#         <Axes: xlabel='acceleration', ylabel='mpg'>,
#         <Axes: xlabel='year', ylabel='mpg'>,
#         <Axes: xlabel='origin', ylabel='mpg'>],
#        [<Axes: xlabel='mpg', ylabel='cylinders'>,
#         <Axes: xlabel='cylinders', ylabel='cylinders'>,
#         <Axes: xlabel='displacement', ylabel='cylinders'>,
#         <Axes: xlabel='weight', ylabel='cylinders'>,
#         <Axes: xlabel='acceleration', ylabel='cylinders'>,
#         <Axes: xlabel='year', ylabel='cylinders'>,
#         <Axes: xlabel='origin', ylabel='cylinders'>],
#        [<Axes: xlabel='mpg', ylabel='displacement'>,
#         <Axes: xlabel='cylinders', ylabel='displacement'>,
#         <Axes: xlabel='displacement', ylabel='displacement'>,
#         <Axes: xlabel='weight', ylabel='displacement'>,
# ...

# %% [markdown]
# according to the graph, cylinders, displacement, weight, acceleration and year affects mpg. It seems that different origins don't have significantly different msgs.
